# %% [markdown]
# We are going to be exploring the MNIST dataset today for a number classification task !

# %% [markdown]
# # Loading and exploring the dataset

# %%
from sklearn.datasets import fetch_openml
import numpy as np

# Fetch MNIST dataset
mnist = fetch_openml('mnist_784', version=1, as_frame=False)  # Optional but smart
X, y = mnist["data"], mnist["target"]

# Convert to NumPy arrays (if not already NumPy due to `as_frame=False`)
X = np.array(X)
y = np.array(y, dtype=int)  # Make sure y is integer (not string)

# Now everything is NumPy and happy 😌
print(X.shape)  # (70000, 784)
print(y[0])     # e.g., 5
# Out:
# (70000, 784)
# 5

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
print(X.shape)

for i in range(0,10):
    print(y[i])
    someDigitArray = X[i]
    someDigitImage = someDigitArray.reshape(28,28)
    plt.imshow(someDigitImage,cmap='binary')
    plt.axis("off")
    plt.show()
# Out:
# (70000, 784)
# 5
# 0
# 4
# 1
# 9
# 2
# 1
# 3
# 1
# 4

# %%
X_train,X_test,y_train,y_test = X[:60000], X[60000:], y[:60000], y[60000:]
